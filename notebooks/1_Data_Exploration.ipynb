# %%
# Import necessary libraries
import pandas as pd
import os
import sys

# Add the parent directory (utils folder) to the system path to import our custom module
# This ensures that our notebook can find the data_loader.py file.
sys.path.append(os.path.join(os.getcwd(), '..'))

# Import our custom data loading function
from utils.data_loader import load_and_clean_data

# ---
# # 1. Project Introduction and Data Loading
#
# In this notebook, we'll perform an initial exploration of the Airbnb datasets for Berlin, Istanbul, and Munich. We'll use our custom `load_and_clean_data` function to load the data, which also handles basic cleaning and saves a processed version for later use.
# ---

# Load and clean datasets for all three cities
df_berlin = load_and_clean_data('berlin')
df_istanbul = load_and_clean_data('istanbul')
df_munich = load_and_clean_data('munich')

# Create a dictionary for easy access to the dataframes
datasets = {
    'Berlin': df_berlin,
    'Istanbul': df_istanbul,
    'Munich': df_munich
}

# ---
# # 2. Initial Data Inspection
#
# After loading and cleaning the data, it's a good practice to inspect its structure, check for data types, and review a few rows to ensure everything is correct.
# ---

for name, df in datasets.items():
    print(f"--- Data Inspection for {name} ---")
    
    # Display the first 5 rows
    print("Head of the DataFrame:")
    print(df.head())
    
    # Display columns and data types
    print("\nDataFrame Info:")
    df.info()
    
    # Display summary statistics for numerical columns
    print("\nSummary Statistics:")
    print(df.describe())
    
    print("\n" + "="*50 + "\n")
# Out:
# Loading and cleaning raw data for Berlin...
# Cleaned data for Berlin saved to: C:\Users\sonic\Documents\GitHub\Airbnb_Price_Analysis\data\berlin\processed\berlin_cleaned.csv
# Loading and cleaning raw data for Istanbul...
# Cleaned data for Istanbul saved to: C:\Users\sonic\Documents\GitHub\Airbnb_Price_Analysis\data\istanbul\processed\istanbul_cleaned.csv
# Loading and cleaning raw data for Munich...
# Cleaned data for Munich saved to: C:\Users\sonic\Documents\GitHub\Airbnb_Price_Analysis\data\munich\processed\munich_cleaned.csv
# --- Data Inspection for Berlin ---
# Head of the DataFrame:
#       id  host_id  host_since           host_location  host_response_time  \
# 0   3176     3718  2008-10-19     Coledale, Australia  within a few hours
# 1   9991    33852  2009-08-25         Berlin, Germany        within a day
# 2  14325    55531  2009-11-18         Berlin, Germany        within a day
# 4  17904    68997  2010-01-08  Rio de Janeiro, Brazil      within an hour
# 6  22438    86159  2010-02-27         Berlin, Germany      within an hour
#
#   host_response_rate host_acceptance_rate host_is_superhost  \
# 0               100%                  80%                 f
# 1                50%                   0%                 f
# 2               100%                  25%                 t
# 4               100%                  94%                 f
# 6               100%                  70%                 t
#
#    host_listings_count  host_total_listings_count  ... review_scores_checkin  \
# 0                  1.0                        1.0  ...                  4.65
# 1                  1.0                        1.0  ...                  5.00
# 2                  4.0                        5.0  ...                  4.70
# 4                  2.0                        5.0  ...                  4.89
# 6                  2.0                        5.0  ...                  4.82
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.70                   4.92                4.61
# 1                        5.00                   4.86                4.86
# 2                        4.85                   4.60                4.45
# 4                        4.92                   4.88                4.65
# 6                        4.73                   4.63                4.68
#
#   instant_bookable  calculated_host_listings_count  \
# 0                f                               1
# 1                f                               1
# 2                f                               4
# 4                f                               1
# 6                f                               1
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            1
# 1                                            1
# 2                                            4
# 4                                            1
# 6                                            1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            0
# 4                                            0
# 6                                            0
#
#   calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                           0               0.76
# 1                                           0               0.06
# 2                                           0               0.14
# 4                                           0               1.60
# 6                                           0               1.05
#
# [5 rows x 62 columns]
#
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9135 entries, 0 to 14186
# Data columns (total 62 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            9135 non-null   int64
#  1   host_id                                       9135 non-null   int64
#  2   host_since                                    9134 non-null   object
#  3   host_location                                 6955 non-null   object
#  4   host_response_time                            8013 non-null   object
#  5   host_response_rate                            8013 non-null   object
#  6   host_acceptance_rate                          8172 non-null   object
#  7   host_is_superhost                             8954 non-null   object
#  8   host_listings_count                           9134 non-null   float64
#  9   host_total_listings_count                     9134 non-null   float64
#  10  host_verifications                            9134 non-null   object
#  11  host_has_profile_pic                          9134 non-null   object
#  12  host_identity_verified                        9134 non-null   object
#  13  neighbourhood_cleansed                        9135 non-null   object
#  14  neighbourhood_group_cleansed                  9135 non-null   object
#  15  latitude                                      9135 non-null   float64
#  16  longitude                                     9135 non-null   float64
#  17  property_type                                 9135 non-null   object
#  18  room_type                                     9135 non-null   object
#  19  accommodates                                  9135 non-null   int64
#  20  bathrooms                                     9131 non-null   float64
#  21  bathrooms_text                                9130 non-null   object
#  22  bedrooms                                      9104 non-null   float64
#  23  beds                                          9119 non-null   float64
#  24  amenities                                     9135 non-null   object
#  25  price                                         9135 non-null   float64
#  26  minimum_nights                                9135 non-null   int64
#  27  maximum_nights                                9135 non-null   int64
#  28  minimum_minimum_nights                        9135 non-null   int64
#  29  maximum_minimum_nights                        9135 non-null   int64
#  30  minimum_maximum_nights                        9135 non-null   int64
#  31  maximum_maximum_nights                        9135 non-null   int64
#  32  minimum_nights_avg_ntm                        9135 non-null   float64
#  33  maximum_nights_avg_ntm                        9135 non-null   float64
#  34  has_availability                              8993 non-null   object
#  35  availability_30                               9135 non-null   int64
#  36  availability_60                               9135 non-null   int64
#  37  availability_90                               9135 non-null   int64
#  38  availability_365                              9135 non-null   int64
#  39  calendar_last_scraped                         9135 non-null   object
#  40  number_of_reviews                             9135 non-null   int64
#  41  number_of_reviews_ltm                         9135 non-null   int64
#  42  number_of_reviews_l30d                        9135 non-null   int64
#  43  availability_eoy                              9135 non-null   int64
#  44  number_of_reviews_ly                          9135 non-null   int64
#  45  estimated_occupancy_l365d                     9135 non-null   int64
#  46  estimated_revenue_l365d                       9135 non-null   float64
#  47  first_review                                  7090 non-null   object
#  48  last_review                                   7090 non-null   object
#  49  review_scores_rating                          7090 non-null   float64
#  50  review_scores_accuracy                        7090 non-null   float64
#  51  review_scores_cleanliness                     7090 non-null   float64
#  52  review_scores_checkin                         7090 non-null   float64
#  53  review_scores_communication                   7090 non-null   float64
#  54  review_scores_location                        7090 non-null   float64
#  55  review_scores_value                           7090 non-null   float64
#  56  instant_bookable                              9135 non-null   object
#  57  calculated_host_listings_count                9135 non-null   int64
#  58  calculated_host_listings_count_entire_homes   9135 non-null   int64
#  59  calculated_host_listings_count_private_rooms  9135 non-null   int64
#  60  calculated_host_listings_count_shared_rooms   9135 non-null   int64
#  61  reviews_per_month                             7090 non-null   float64
# dtypes: float64(19), int64(23), object(20)
# memory usage: 4.4+ MB
#
# Summary Statistics:
#                  id       host_id  host_listings_count  \
# count  9.135000e+03  9.135000e+03          9134.000000
# mean   6.338917e+17  2.205375e+08            30.901029
# std    5.609110e+17  2.172615e+08           116.591738
# min    3.176000e+03  1.581000e+03             1.000000
# 25%    3.299538e+07  1.878385e+07             1.000000
# 50%    7.688465e+17  1.408945e+08             2.000000
# 75%    1.162111e+18  4.344854e+08             8.000000
# max    1.447175e+18  7.016200e+08          1319.000000
#
#        host_total_listings_count     latitude    longitude  accommodates  \
# count                9134.000000  9135.000000  9135.000000   9135.000000
# mean                   34.530983    52.508738    13.400293      3.296223
# std                   130.025288     0.035361     0.073387      2.084445
# min                     1.000000    52.340027    13.118150      1.000000
# 25%                     1.000000    52.491157    13.356022      2.000000
# 50%                     3.000000    52.509673    13.406256      2.000000
# 75%                    11.000000    52.531639    13.437175      4.000000
# max                  2002.000000    52.650760    13.737270     16.000000
#
#          bathrooms     bedrooms         beds  ...  review_scores_cleanliness  \
# count  9131.000000  9104.000000  9119.000000  ...                7090.000000
# mean      1.151791     1.325022     2.013269  ...                   4.713343
# std       0.472707     0.830675     1.654303  ...                   0.395204
# min       0.000000     0.000000     0.000000  ...                   0.000000
# 25%       1.000000     1.000000     1.000000  ...                   4.620000
# 50%       1.000000     1.000000     1.000000  ...                   4.820000
# 75%       1.000000     2.000000     2.000000  ...                   4.950000
# max      15.000000     9.000000    50.000000  ...                   5.000000
#
#        review_scores_checkin  review_scores_communication  \
# count            7090.000000                  7090.000000
# mean                4.820049                     4.806285
# std                 0.336088                     0.386935
# min                 0.000000                     0.000000
# 25%                 4.790000                     4.780000
# 50%                 4.910000                     4.920000
# 75%                 5.000000                     5.000000
# max                 5.000000                     5.000000
#
#        review_scores_location  review_scores_value  \
# count             7090.000000          7090.000000
# mean                 4.756760             4.617726
# std                  0.323669             0.420355
# min                  0.000000             0.000000
# 25%                  4.670000             4.520000
# 50%                  4.830000             4.710000
# 75%                  4.950000             4.840000
# max                  5.000000             5.000000
#
#        calculated_host_listings_count  \
# count                     9135.000000
# mean                        17.289874
# std                         54.925882
# min                          1.000000
# 25%                          1.000000
# 50%                          2.000000
# 75%                          7.000000
# max                        323.000000
#
#        calculated_host_listings_count_entire_homes  \
# count                                  9135.000000
# mean                                     14.833169
# std                                      53.730888
# min                                       0.000000
# 25%                                       1.000000
# 50%                                       1.000000
# 75%                                       5.000000
# max                                     323.000000
#
#        calculated_host_listings_count_private_rooms  \
# count                                   9135.000000
# mean                                       2.175588
# std                                       11.746242
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        1.000000
# max                                      109.000000
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# count                                  9135.000000        7090.000000
# mean                                      0.209086           1.719234
# std                                       1.758792           2.215759
# min                                       0.000000           0.010000
# 25%                                       0.000000           0.360000
# 50%                                       0.000000           1.090000
# 75%                                       0.000000           2.460000
# max                                      22.000000          50.070000
#
# [8 rows x 42 columns]
#
# ==================================================
#
# --- Data Inspection for Istanbul ---
# Head of the DataFrame:
#         id  host_id  host_since     host_location  host_response_time  \
# 12  750291  1806816  2012-02-25  Istanbul, Turkey  within a few hours
# 17  135956   666066  2011-06-05  İstanbul, Turkey  within a few hours
# 33  191058   666066  2011-06-05  İstanbul, Turkey  within a few hours
# 34  191069   666066  2011-06-05  İstanbul, Turkey  within a few hours
# 51  256825  1351134  2011-10-30  İstanbul, Turkey                 NaN
#
#    host_response_rate host_acceptance_rate host_is_superhost  \
# 12               100%                  86%                 f
# 17               100%                 100%                 t
# 33               100%                 100%                 t
# 34               100%                 100%                 t
# 51                NaN                  18%                 f
#
#     host_listings_count  host_total_listings_count  ...  \
# 12                  7.0                       12.0  ...
# 17                  8.0                       38.0  ...
# 33                  8.0                       38.0  ...
# 34                  8.0                       38.0  ...
# 51                  5.0                       19.0  ...
#
#    review_scores_communication review_scores_location review_scores_value  \
# 12                        4.86                   4.53                4.53
# 17                        4.90                   4.83                4.71
# 33                        4.89                   4.94                4.81
# 34                        4.79                   4.80                4.63
# 51                        4.86                   4.55                4.59
#
#    license  instant_bookable  calculated_host_listings_count  \
# 12     NaN                 f                               7
# 17  Exempt                 f                               8
# 33     NaN                 f                               8
# 34  Exempt                 f                               8
# 51     NaN                 f                               5
#
#    calculated_host_listings_count_entire_homes  \
# 12                                           1
# 17                                           4
# 33                                           4
# 34                                           4
# 51                                           0
#
#    calculated_host_listings_count_private_rooms  \
# 12                                            6
# 17                                            4
# 33                                            4
# 34                                            4
# 51                                            5
#
#     calculated_host_listings_count_shared_rooms  reviews_per_month
# 12                                            0               0.10
# 17                                            0               0.26
# 33                                            0               0.25
# 34                                            0               0.20
# 51                                            0               1.56
#
# [5 rows x 62 columns]
#
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3340 entries, 12 to 29981
# Data columns (total 62 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            3340 non-null   int64
#  1   host_id                                       3340 non-null   int64
#  2   host_since                                    3340 non-null   object
#  3   host_location                                 2024 non-null   object
#  4   host_response_time                            1774 non-null   object
#  5   host_response_rate                            1774 non-null   object
#  6   host_acceptance_rate                          2357 non-null   object
#  7   host_is_superhost                             3305 non-null   object
#  8   host_listings_count                           3340 non-null   float64
#  9   host_total_listings_count                     3340 non-null   float64
#  10  host_verifications                            3340 non-null   object
#  11  host_has_profile_pic                          3340 non-null   object
#  12  host_identity_verified                        3340 non-null   object
#  13  neighbourhood_cleansed                        3340 non-null   object
#  14  latitude                                      3340 non-null   float64
#  15  longitude                                     3340 non-null   float64
#  16  property_type                                 3340 non-null   object
#  17  room_type                                     3340 non-null   object
#  18  accommodates                                  3340 non-null   int64
#  19  bathrooms                                     3312 non-null   float64
#  20  bathrooms_text                                3312 non-null   object
#  21  bedrooms                                      3307 non-null   float64
#  22  beds                                          3335 non-null   float64
#  23  amenities                                     3340 non-null   object
#  24  price                                         3340 non-null   float64
#  25  minimum_nights                                3340 non-null   int64
#  26  maximum_nights                                3340 non-null   int64
#  27  minimum_minimum_nights                        3340 non-null   float64
#  28  maximum_minimum_nights                        3340 non-null   float64
#  29  minimum_maximum_nights                        3340 non-null   float64
#  30  maximum_maximum_nights                        3340 non-null   float64
#  31  minimum_nights_avg_ntm                        3340 non-null   float64
#  32  maximum_nights_avg_ntm                        3340 non-null   float64
#  33  has_availability                              3158 non-null   object
#  34  availability_30                               3340 non-null   int64
#  35  availability_60                               3340 non-null   int64
#  36  availability_90                               3340 non-null   int64
#  37  availability_365                              3340 non-null   int64
#  38  calendar_last_scraped                         3340 non-null   object
#  39  number_of_reviews                             3340 non-null   int64
#  40  number_of_reviews_ltm                         3340 non-null   int64
#  41  number_of_reviews_l30d                        3340 non-null   int64
#  42  availability_eoy                              3340 non-null   int64
#  43  number_of_reviews_ly                          3340 non-null   int64
#  44  estimated_occupancy_l365d                     3340 non-null   int64
#  45  estimated_revenue_l365d                       3340 non-null   float64
#  46  first_review                                  1560 non-null   object
#  47  last_review                                   1560 non-null   object
#  48  review_scores_rating                          1560 non-null   float64
#  49  review_scores_accuracy                        1560 non-null   float64
#  50  review_scores_cleanliness                     1560 non-null   float64
#  51  review_scores_checkin                         1560 non-null   float64
#  52  review_scores_communication                   1560 non-null   float64
#  53  review_scores_location                        1560 non-null   float64
#  54  review_scores_value                           1559 non-null   float64
#  55  license                                       854 non-null    object
#  56  instant_bookable                              3340 non-null   object
#  57  calculated_host_listings_count                3340 non-null   int64
#  58  calculated_host_listings_count_entire_homes   3340 non-null   int64
#  59  calculated_host_listings_count_private_rooms  3340 non-null   int64
#  60  calculated_host_listings_count_shared_rooms   3340 non-null   int64
#  61  reviews_per_month                             1560 non-null   float64
# dtypes: float64(23), int64(19), object(20)
# memory usage: 1.6+ MB
#
# Summary Statistics:
#                  id       host_id  host_listings_count  \
# count  3.340000e+03  3.340000e+03          3340.000000
# mean   8.202836e+17  3.825990e+08             5.686826
# std    4.109772e+17  1.790140e+08            11.229513
# min    1.359560e+05  8.592300e+04             1.000000
# 25%    7.048552e+17  2.648293e+08             1.000000
# 50%    9.058207e+17  4.540900e+08             2.000000
# 75%    1.086891e+18  5.081429e+08             5.000000
# max    1.384765e+18  6.853188e+08           200.000000
#
#        host_total_listings_count     latitude    longitude  accommodates  \
# count                3340.000000  3340.000000  3340.000000   3340.000000
# mean                    7.612575    41.023562    28.965554      2.094611
# std                    14.468901     0.051642     0.148239      1.631168
# min                     1.000000    40.816730    28.035130      1.000000
# 25%                     1.000000    40.995950    28.946163      1.000000
# 50%                     3.000000    41.025263    28.983927      2.000000
# 75%                     7.000000    41.047866    29.029862      2.000000
# max                   216.000000    41.334259    29.859670     16.000000
#
#          bathrooms     bedrooms         beds  ...  review_scores_cleanliness  \
# count  3312.000000  3307.000000  3335.000000  ...                1560.000000
# mean      1.202748     1.197158     1.663568  ...                   4.417750
# std       1.337448     0.924142     3.536192  ...                   0.841822
# min       0.000000     0.000000     0.000000  ...                   1.000000
# 25%       1.000000     1.000000     1.000000  ...                   4.240000
# 50%       1.000000     1.000000     1.000000  ...                   4.700000
# 75%       1.000000     1.000000     2.000000  ...                   5.000000
# max      25.000000    25.000000    50.000000  ...                   5.000000
#
#        review_scores_checkin  review_scores_communication  \
# count            1560.000000                  1560.000000
# mean                4.648756                     4.665045
# std                 0.748286                     0.756531
# min                 1.000000                     1.000000
# 25%                 4.670000                     4.717500
# 50%                 4.940000                     4.960000
# 75%                 5.000000                     5.000000
# max                 5.000000                     5.000000
#
#        review_scores_location  review_scores_value  \
# count             1560.000000          1559.000000
# mean                 4.573827             4.521764
# std                  0.724512             0.824179
# min                  1.000000             1.000000
# 25%                  4.500000             4.500000
# 50%                  4.830000             4.800000
# 75%                  5.000000             5.000000
# max                  5.000000             5.000000
#
#        calculated_host_listings_count  \
# count                     3340.000000
# mean                         5.253892
# std                         10.664570
# min                          1.000000
# 25%                          1.000000
# 50%                          2.000000
# 75%                          5.000000
# max                        197.000000
#
#        calculated_host_listings_count_entire_homes  \
# count                                  3340.000000
# mean                                      2.304790
# std                                       7.621821
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       0.000000
# 75%                                       1.000000
# max                                     196.000000
#
#        calculated_host_listings_count_private_rooms  \
# count                                   3340.000000
# mean                                       2.837126
# std                                        6.655638
# min                                        0.000000
# 25%                                        1.000000
# 50%                                        1.000000
# 75%                                        2.000000
# max                                       48.000000
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# count                                  3340.000000        1560.000000
# mean                                      0.088024           0.691590
# std                                       0.708508           1.007369
# min                                       0.000000           0.010000
# 25%                                       0.000000           0.110000
# 50%                                       0.000000           0.285000
# 75%                                       0.000000           0.860000
# max                                      11.000000           8.490000
#
# [8 rows x 42 columns]
#
# ==================================================
#
# --- Data Inspection for Munich ---
# Head of the DataFrame:
#        id  host_id  host_since    host_location  host_response_time  \
# 0   97945   517685  2011-04-18  Munich, Germany                 NaN
# 1  114695   581737  2011-05-12  Munich, Germany      within an hour
# 2  127383   630556  2011-05-26  Munich, Germany  within a few hours
# 4  170154   108297  2010-04-14  Munich, Germany        within a day
# 6  172977   825767  2011-07-16  Munich, Germany  within a few hours
#
#   host_response_rate host_acceptance_rate host_is_superhost  \
# 0                NaN                   0%                 f
# 1               100%                  97%                 t
# 2               100%                  86%                 f
# 4               100%                 100%                 t
# 6               100%                  77%                 f
#
#    host_listings_count  host_total_listings_count  ... review_scores_checkin  \
# 0                  2.0                        4.0  ...                  4.90
# 1                  3.0                        3.0  ...                  4.97
# 2                  2.0                        2.0  ...                  4.98
# 4                  1.0                        1.0  ...                  4.99
# 6                  1.0                        1.0  ...                  4.89
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.93                   4.78                4.73
# 1                        5.00                   4.66                4.62
# 2                        4.96                   4.91                4.81
# 4                        4.98                   4.78                4.91
# 6                        4.89                   4.80                4.76
#
#    instant_bookable  calculated_host_listings_count  \
# 0                 f                               2
# 1                 f                               3
# 2                 f                               1
# 4                 f                               1
# 6                 f                               1
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           2
# 1                                           3
# 2                                           1
# 4                                           0
# 6                                           0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            0
# 4                                            1
# 6                                            1
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               0.75
# 1                                            0               0.46
# 2                                            0               0.68
# 4                                            0               3.49
# 6                                            0               0.74
#
# [5 rows x 61 columns]
#
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4687 entries, 0 to 7141
# Data columns (total 61 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            4687 non-null   int64
#  1   host_id                                       4687 non-null   int64
#  2   host_since                                    4502 non-null   object
#  3   host_location                                 3377 non-null   object
#  4   host_response_time                            4023 non-null   object
#  5   host_response_rate                            4023 non-null   object
#  6   host_acceptance_rate                          4294 non-null   object
#  7   host_is_superhost                             4642 non-null   object
#  8   host_listings_count                           4502 non-null   float64
#  9   host_total_listings_count                     4502 non-null   float64
#  10  host_verifications                            4502 non-null   object
#  11  host_has_profile_pic                          4502 non-null   object
#  12  host_identity_verified                        4502 non-null   object
#  13  neighbourhood_cleansed                        4687 non-null   object
#  14  latitude                                      4687 non-null   float64
#  15  longitude                                     4687 non-null   float64
#  16  property_type                                 4687 non-null   object
#  17  room_type                                     4687 non-null   object
#  18  accommodates                                  4687 non-null   int64
#  19  bathrooms                                     4684 non-null   float64
#  20  bathrooms_text                                4683 non-null   object
#  21  bedrooms                                      4682 non-null   float64
#  22  beds                                          4685 non-null   float64
#  23  amenities                                     4687 non-null   object
#  24  price                                         4687 non-null   float64
#  25  minimum_nights                                4687 non-null   int64
#  26  maximum_nights                                4687 non-null   int64
#  27  minimum_minimum_nights                        4685 non-null   float64
#  28  maximum_minimum_nights                        4685 non-null   float64
#  29  minimum_maximum_nights                        4685 non-null   float64
#  30  maximum_maximum_nights                        4685 non-null   float64
#  31  minimum_nights_avg_ntm                        4687 non-null   float64
#  32  maximum_nights_avg_ntm                        4687 non-null   float64
#  33  has_availability                              4610 non-null   object
#  34  availability_30                               4687 non-null   int64
#  35  availability_60                               4687 non-null   int64
#  36  availability_90                               4687 non-null   int64
#  37  availability_365                              4687 non-null   int64
#  38  calendar_last_scraped                         4687 non-null   object
#  39  number_of_reviews                             4687 non-null   int64
#  40  number_of_reviews_ltm                         4687 non-null   int64
#  41  number_of_reviews_l30d                        4687 non-null   int64
#  42  availability_eoy                              4687 non-null   int64
#  43  number_of_reviews_ly                          4687 non-null   int64
#  44  estimated_occupancy_l365d                     4687 non-null   int64
#  45  estimated_revenue_l365d                       4687 non-null   float64
#  46  first_review                                  3852 non-null   object
#  47  last_review                                   3852 non-null   object
#  48  review_scores_rating                          3852 non-null   float64
#  49  review_scores_accuracy                        3852 non-null   float64
#  50  review_scores_cleanliness                     3852 non-null   float64
#  51  review_scores_checkin                         3852 non-null   float64
#  52  review_scores_communication                   3852 non-null   float64
#  53  review_scores_location                        3852 non-null   float64
#  54  review_scores_value                           3852 non-null   float64
#  55  instant_bookable                              4687 non-null   object
#  56  calculated_host_listings_count                4687 non-null   int64
#  57  calculated_host_listings_count_entire_homes   4687 non-null   int64
#  58  calculated_host_listings_count_private_rooms  4687 non-null   int64
#  59  calculated_host_listings_count_shared_rooms   4687 non-null   int64
#  60  reviews_per_month                             3852 non-null   float64
# dtypes: float64(23), int64(19), object(19)
# memory usage: 2.2+ MB
#
# Summary Statistics:
#                  id       host_id  host_listings_count  \
# count  4.687000e+03  4.687000e+03          4502.000000
# mean   7.595125e+17  2.301071e+08             8.648156
# std    5.475609e+17  2.164675e+08            55.763622
# min    9.794500e+04  1.581000e+03             1.000000
# 25%    4.539887e+07  2.960790e+07             1.000000
# 50%    9.471253e+17  1.495496e+08             1.000000
# 75%    1.236926e+18  4.163669e+08             3.000000
# max    1.450177e+18  7.031024e+08          1244.000000
#
#        host_total_listings_count     latitude    longitude  accommodates  \
# count                4502.000000  4687.000000  4687.000000   4687.000000
# mean                   10.908041    48.139183    11.563113      2.798378
# std                    66.473335     0.026555     0.053980      1.727639
# min                     1.000000    48.069060    11.388350      1.000000
# 25%                     1.000000    48.122128    11.537227      2.000000
# 50%                     2.000000    48.136648    11.564717      2.000000
# 75%                     4.000000    48.155524    11.588128      4.000000
# max                  1421.000000    48.228020    11.716110     16.000000
#
#          bathrooms     bedrooms         beds  ...  review_scores_cleanliness  \
# count  4684.000000  4682.000000  4685.000000  ...                3852.000000
# mean      1.135034     1.216574     1.677695  ...                   4.730047
# std       0.407552     1.003561     1.428432  ...                   0.418938
# min       0.000000     0.000000     0.000000  ...                   1.000000
# 25%       1.000000     1.000000     1.000000  ...                   4.650000
# 50%       1.000000     1.000000     1.000000  ...                   4.860000
# 75%       1.000000     1.000000     2.000000  ...                   5.000000
# max       8.000000    50.000000    40.000000  ...                   5.000000
#
#        review_scores_checkin  review_scores_communication  \
# count            3852.000000                  3852.000000
# mean                4.842957                     4.854943
# std                 0.310231                     0.311686
# min                 0.000000                     1.000000
# 25%                 4.807500                     4.830000
# 50%                 4.940000                     4.970000
# 75%                 5.000000                     5.000000
# max                 5.000000                     5.000000
#
#        review_scores_location  review_scores_value  \
# count             3852.000000          3852.000000
# mean                 4.774572             4.612635
# std                  0.318876             0.428998
# min                  1.000000             1.000000
# 25%                  4.690000             4.500000
# 50%                  4.860000             4.710000
# 75%                  5.000000             4.870000
# max                  5.000000             5.000000
#
#        calculated_host_listings_count  \
# count                     4687.000000
# mean                         3.877320
# std                         10.483677
# min                          1.000000
# 25%                          1.000000
# 50%                          1.000000
# 75%                          2.000000
# max                         78.000000
#
#        calculated_host_listings_count_entire_homes  \
# count                                  4687.000000
# mean                                      2.851291
# std                                      10.146529
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       1.000000
# 75%                                       1.000000
# max                                      78.000000
#
#        calculated_host_listings_count_private_rooms  \
# count                                   4687.000000
# mean                                       1.008748
# std                                        2.897253
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        1.000000
# max                                       24.000000
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# count                                  4687.000000        3852.000000
# mean                                      0.005121           1.273712
# std                                       0.085026           2.066387
# min                                       0.000000           0.010000
# 25%                                       0.000000           0.270000
# 50%                                       0.000000           0.670000
# 75%                                       0.000000           1.500000
# max                                       2.000000          46.420000
#
# [8 rows x 42 columns]
#
# ==================================================
